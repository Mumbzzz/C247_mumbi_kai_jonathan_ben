# %%
# !git clone https://Mumbzzz:"""@github.com/he-is-kai/C247_mumbikaijonathanben.git
# Out:
# Cloning into 'C247_mumbikaijonathanben'...
# remote: Enumerating objects: 566, done.
# remote: Counting objects: 100% (168/168), done.
# remote: Compressing objects: 100% (119/119), done.
# remote: Total 566 (delta 83), reused 123 (delta 47), pack-reused 398 (from 1)
# Receiving objects: 100% (566/566), 376.20 MiB | 17.83 MiB/s, done.
# Resolving deltas: 100% (260/260), done.

# %%
# %cd /content/C247_mumbikaijonathanben
# !git pull origin main
# Out:
# /content/C247_mumbikaijonathanben
# From https://github.com/he-is-kai/C247_mumbikaijonathanben
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA L4

# %%
# %cd /content/C247_mumbikaijonathanben

# !pip install protobuf==3.20.3
# !pip install kenlm
# !pip install unidecode
# !pip install python-Levenshtein
# !pip install torchmetrics
# !pip install h5py==3.11.0
# !pip install -e .
# Out:
# /content/C247_mumbikaijonathanben
# ...
#   Using cached kenlm-0.3.0.tar.gz (427 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for kenlm: filename=kenlm-0.3.0-cp312-cp312-linux_x86_64.whl size=3188097 sha256=f247bfc6a388c294e3094415d9cee630b006eaa5832092833f3bca12b5f219af
#   Stored in directory: /root/.cache/pip/wheels/0c/e6/ad/18d2d3f1290a6be6a14a24e90f2b78bb3300aab3852ceb06a6
# Successfully built kenlm
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.8/235.8 kB 17.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.3/153.3 kB 18.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 118.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 61.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 108.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: h5py
# ...

# %%
import os, shutil
from google.colab import drive

# Mount Drive
drive.mount('/content/drive')
os.chdir("/content/C247_mumbikaijonathanben")

# Fix symlinks
os.makedirs("/content/drive/MyDrive/Classes/ECE247A/C247_results", exist_ok=True)
os.makedirs("/content/drive/MyDrive/Classes/ECE247A/C247_checkpoints", exist_ok=True)

for src, dst in [
    ("/content/drive/MyDrive/Classes/ECE247A/C247_results", "results"),
    ("/content/drive/MyDrive/Classes/ECE247A/C247_checkpoints", "Playground_Mumbi/checkpoints"),
]:
    if os.path.islink(dst):
        os.unlink(dst)
    elif os.path.exists(dst):
        shutil.rmtree(dst)
    os.symlink(src, dst)

# Verify
print(os.path.realpath("results"))
print(os.path.realpath("Playground_Mumbi/checkpoints"))

# !ls -la results/
# !ls -la Playground_Mumbi/checkpoints/
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Classes/ECE247A/C247_results
# /content/drive/MyDrive/Classes/ECE247A/C247_checkpoints
# total 187
# -rw------- 1 root root 144686 Mar 12 17:52 results_curves_CNN_LSTM.csv
# -rw------- 1 root root  39094 Mar  9 02:41 results_curves_CNN_training_fraction_ablation.csv
# -rw------- 1 root root   1014 Mar 12 17:52 results_summary_CNN_LSTM.csv
# -rw------- 1 root root   1209 Mar  9 02:41 results_summary_CNN_training_fraction_ablation.csv
# drwx------ 2 root root   4096 Mar  8 23:59 training_fraction_ablation_plots
# total 15
# -rw------- 1 root root  567 Mar 12 13:00 best_hyperparams_cnn_lstm_latent.yaml
# -rw------- 1 root root  385 Mar 12 00:57 best_hyperparams_cnn_lstm.yaml
# drwx------ 2 root root 4096 Mar  8 06:22 final_models
# drwx------ 2 root root 4096 Mar 12 00:55 .ipynb_checkpoints
# -rw------- 1 root root  756 Mar 12 15:45 log_model_training.txt
# drwx------ 2 root root 4096 Mar  8 04:19 training_fraction_ablation

# %%
# !wget -O 89335547.zip "https://ucla.box.com/shared/static/dy28c8fne2d2bypyc0dz6xnfmmohgoyq"
# Out:
# --2026-03-11 20:10:57--  https://ucla.box.com/shared/static/dy28c8fne2d2bypyc0dz6xnfmmohgoyq
# Resolving ucla.box.com (ucla.box.com)... 74.112.186.157, 2620:117:bff0:12d::
# Connecting to ucla.box.com (ucla.box.com)|74.112.186.157|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/dy28c8fne2d2bypyc0dz6xnfmmohgoyq [following]
# --2026-03-11 20:10:58--  https://ucla.box.com/public/static/dy28c8fne2d2bypyc0dz6xnfmmohgoyq
# Reusing existing connection to ucla.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ucla.app.box.com/public/static/dy28c8fne2d2bypyc0dz6xnfmmohgoyq [following]
# --2026-03-11 20:10:58--  https://ucla.app.box.com/public/static/dy28c8fne2d2bypyc0dz6xnfmmohgoyq
# Resolving ucla.app.box.com (ucla.app.box.com)... 74.112.186.157, 2620:117:bff0:12d::
# Connecting to ucla.app.box.com (ucla.app.box.com)|74.112.186.157|:443... connected.
# ...

# %%
# !unzip 89335547.zip
# !mkdir -p data/89335547
# !mv 89335547/* data/89335547/
# !rm 89335547.zip
# !ls data/89335547
# Out:
# Archive:  89335547.zip
#   inflating: 89335547/2021-06-02-1622679967-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f.hdf5
#   inflating: 89335547/2021-06-03-1622764398-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f.hdf5
#   inflating: 89335547/2021-06-04-1622862148-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f.hdf5
#   inflating: 89335547/2021-06-02-1622682789-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f.hdf5
#   inflating: 89335547/2021-06-03-1622765527-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f.hdf5
#   inflating: 89335547/2021-06-03-1622766673-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f.hdf5
#   inflating: 89335547/2021-06-04-1622861066-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f.hdf5
#   inflating: 89335547/2021-06-02-1622681518-keystrokes-dca-study@1-0efbe614-9ae6-4131-9192-4398359b4f5f.hdf5
# ...

# %%
##############################################################3
# CNN training ablation

# %cd /content/C247_mumbikaijonathanben
# !git pull origin main

# !python -m Playground_Mumbi.train \
    --model cnn \
    --epochs 80 \
    --batch-size 32 \
    --num-workers 2 \
    --run-all-fractions
# Out:
# /content/C247_mumbikaijonathanben
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0 (from 0)
# Unpacking objects: 100% (3/3), 318 bytes | 318.00 KiB/s, done.
# From https://github.com/he-is-kai/C247_mumbikaijonathanben
#  * branch            main       -> FETCH_HEAD
#    7a20c1f..72155a3  main       -> origin/main
# Updating 7a20c1f..72155a3
# Fast-forward
#  .../{results_curves_CONFORMER.csv => kai_results_curves_CONFORMER.csv}    | 0
#  results/{results_curves_RNN.csv => kai_results_curves_RNN.csv}            | 0
#  .../{results_summary_CONFORMER.csv => kai_results_summary_CONFORMER.csv}  | 0
#  results/{results_summary_RNN.csv => kai_results_summary_RNN.csv}          | 0
#  4 files changed, 0 insertions(+), 0 deletions(-)
#  rename results/{results_curves_CONFORMER.csv => kai_results_curves_CONFORMER.csv} (100%)
# ...

# %%
# Save -- CNN training ablation
import pandas as pd
df = pd.read_csv("results/results_summary_CNN.csv")
print(df[["run_id", "train_fraction", "final_val_cer", "test_cer"]])

from google.colab import files
files.download("results/results_summary_CNN.csv")
files.download("results/results_curves_CNN.csv")
files.download("Playground_Mumbi/checkpoints/final_models/best_cnn.pt")


# !python -m Playground_Mumbi.plot_results

from google.colab import files
files.download("results/training_fraction_ablation_plots/cer_vs_fraction_CNN.png")
files.download("results/training_fraction_ablation_plots/training_curves_CNN.png")
files.download("results/training_fraction_ablation_plots/training_time_CNN.png")
# Out:
#                                    run_id  train_fraction  final_val_cer  \
# 0   CNN_32ch_2000hz_10pct_20260308_235251            0.10      45.547187
# 1   CNN_32ch_2000hz_25pct_20260309_000202            0.25      28.223305
# 2   CNN_32ch_2000hz_50pct_20260309_001946            0.50      23.039433
# 3   CNN_32ch_2000hz_75pct_20260309_005133            0.75      21.089942
# 4  CNN_32ch_2000hz_100pct_20260309_013738            1.00      18.852459
#
#     test_cer
# 0  39.259420
# 1  30.099610
# 2  24.880901
# 3  22.152447
# 4  21.242962
# [plot_results] saved /content/C247_mumbikaijonathanben/Playground_Mumbi/../results/training_fraction_ablation_plots/cer_vs_fraction_CNN.png
# [plot_results] saved /content/C247_mumbikaijonathanben/Playground_Mumbi/../results/training_fraction_ablation_plots/training_curves_CNN.png
# [plot_results] saved /content/C247_mumbikaijonathanben/Playground_Mumbi/../results/training_fraction_ablation_plots/training_time_CNN.png
# [plot_results] Done.

# %%
############################################################
# Hybrid (Baseline) hyper param tuner
# %cd /content/C247_mumbikaijonathanben
# !git pull origin main

# !python -m Playground_Mumbi.hyperparam_tuner \
      --trial-sessions 8 \
      --coarse-trials 20 \
      --coarse-epochs 60 \
      --fine-trials 10 \
      --fine-epochs 80 \
      --trial-timeout 300 \
      --early-stopping-patience 10 \
      --batch-size 32

from google.colab import files
files.download("Playground_Mumbi/checkpoints/best_hyperparams_cnn_lstm.yaml")
# Out:
# /content/C247_mumbikaijonathanben
# From https://github.com/he-is-kai/C247_mumbikaijonathanben
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# Device            : cuda
# Model             : CNN+LSTM
# Channels/hand     : 16  indices=all
# Search mode       : two-phase
# Train sessions    : 8 / 16
# Val sessions      : 1
# Coarse            : 20 trials x 60 epochs
# Fine              : 3 anchors x 10 trials x 80 epochs
# Fine shrink       : 3.0x (continuous params)
# Trial timeout     : 300s (checked between epochs)
# Early stopping    : patience=10
# Search params     : ['lr', 'cnn_channels', 'cnn_kernel', 'cnn_layers', 'lstm_hidden', 'lstm_layers', 'dropout', 'weight_decay']
# Press Ctrl+C to stop early — completed trials will still be ranked.
#
# ...
#   PHASE C — Coarse search  (20 trials, 60 epochs each)
# ...
# [C] Trial   1/20  lr=1.90e-03  cnn_ch=128  cnn_k=7  cnn_l=2  lstm_h=256  lstm_l=1  do=0.156  wd=2.57e-05  -> val_CER=69.85%  (300.5s)  [timeout]
# ...

# %%
# Hyrbid (Baseline) training
# %cd /content/C247_mumbikaijonathanben
# !git pull origin main

# !python -m Playground_Mumbi.train \
    --model cnn_lstm \
    --epochs 150 \
    --from-hyperparams Playground_Mumbi/checkpoints/best_hyperparams_cnn_lstm.yaml \
    --batch-size 32 \
    --num-workers 2


from google.colab import files
files.download("results/results_summary_CNN_LSTM.csv")
files.download("results/results_curves_CNN_LSTM.csv")
files.download("Playground_Mumbi/checkpoints/final_models/best_cnnlstm.pt")
# Out:
# /content/C247_mumbikaijonathanben
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 4 (delta 3), reused 4 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (4/4), 792 bytes | 792.00 KiB/s, done.
# From https://github.com/he-is-kai/C247_mumbikaijonathanben
#  * branch            main       -> FETCH_HEAD
#    ac79695..c288a44  main       -> origin/main
# Updating ac79695..c288a44
# Fast-forward
#  Playground_Mumbi/train_latent.py | 18 ++++++++++++++++--
#  1 file changed, 16 insertions(+), 2 deletions(-)
# Loaded hyperparameters from: Playground_Mumbi/checkpoints/best_hyperparams_cnn_lstm.yaml
#   lr = 0.0016150314867822216
#   weight_decay = 4.471967886953457e-05
#   cnn_channels = 384
#   cnn_kernel = 3
#   cnn_layers = 3
#   lstm_hidden = 512
#   lstm_layers = 1
#   dropout = 0.17743104178493208
#
# ...
# train_fraction = 1.00  |  notes = arch_comparison
# Device         : cuda
# ...

# %%
######################################
# Train w Biophys

# %cd /content/C247_mumbikaijonathanben
# !git pull origin main

# !python -m Playground_Mumbi.train \
    --model cnn_lstm \
    --biophys \
    --from-hyperparams Playground_Mumbi/checkpoints/best_hyperparams_cnn_lstm.yaml \
    --epochs 150 \
    --batch-size 32 \
    --num-workers 2 \
    --checkpoint-dir /content/drive/MyDrive/Classes/ECE247A/C247_checkpoints/

from google.colab import files
files.download("Playground_Mumbi/checkpoints/best_cnnlstm_biophys.pt")
files.download('results/results_summary_CNN_LSTM.csv')
files.download('results/results_curves_CNN_LSTM.csv')
# Out:
# /content/C247_mumbikaijonathanben
# From https://github.com/he-is-kai/C247_mumbikaijonathanben
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# Loaded hyperparameters from: Playground_Mumbi/checkpoints/best_hyperparams_cnn_lstm.yaml
#   lr = 0.0016150314867822216
#   weight_decay = 4.471967886953457e-05
#   cnn_channels = 384
#   cnn_kernel = 3
#   cnn_layers = 3
#   lstm_hidden = 512
#   lstm_layers = 1
#   dropout = 0.17743104178493208
#
# ...
# train_fraction = 1.00  |  notes = arch_comparison_biophys
# Device         : cuda
# Building data loaders …
#   train_fraction=1.00: using all 3835 training windows
#   train batches : 120 | val batches : 7 | test batches : 281
# Model       : CNN_LSTM
# Parameters  : 5,750,019
# Run ID      : CNN_LSTM_8ch_1000hz_100pct_20260312_030635
#
# Training for 150 epochs …
# Tip: press Ctrl+C at any time to stop early and jump to test evaluation.
#
# ...

# %%
##############################################
# !wget -O 89335547_recons_v3.zip "https://ucla.box.com/shared/static/rtik65u7bhrllelm99po9ebhowuhnmaf"
# !unzip 89335547_recons_v3.zip
# !mkdir -p data/89335547_recons_v3/
# !mv 89335547_recons_v3/* data/89335547_recons_v3/
# !rm 89335547_recons_v3.zip
# !ls data/89335547_recons_v3/
# Out:
# --2026-03-12 19:23:18--  https://ucla.box.com/shared/static/rtik65u7bhrllelm99po9ebhowuhnmaf
# Resolving ucla.box.com (ucla.box.com)... 74.112.186.157, 2620:117:bff0:12d::
# Connecting to ucla.box.com (ucla.box.com)|74.112.186.157|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /public/static/rtik65u7bhrllelm99po9ebhowuhnmaf [following]
# --2026-03-12 19:23:18--  https://ucla.box.com/public/static/rtik65u7bhrllelm99po9ebhowuhnmaf
# Reusing existing connection to ucla.box.com:443.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://ucla.app.box.com/public/static/rtik65u7bhrllelm99po9ebhowuhnmaf [following]
# --2026-03-12 19:23:19--  https://ucla.app.box.com/public/static/rtik65u7bhrllelm99po9ebhowuhnmaf
# Resolving ucla.app.box.com (ucla.app.box.com)... 74.112.186.157, 2620:117:bff0:12d::
# Connecting to ucla.app.box.com (ucla.app.box.com)|74.112.186.157|:443... connected.
# ...

# %%
# Recons v3 tuner
# %cd /content/C247_mumbikaijonathanben
# !git pull origin main

# !python -m Playground_Mumbi.hyperparam_tuner_recons \
      --trial-sessions 8 \
      --coarse-trials 20 \
      --coarse-epochs 60 \
      --fine-trials 10 \
      --fine-epochs 80 \
      --trial-timeout 300 \
      --early-stopping-patience 10 \
      --batch-size 32

from google.colab import files
files.download("Playground_Mumbi/checkpoints/best_hyperparams_cnn_lstm_recons.yaml")

# %%
# Train w Recons v3

# %cd /content/C247_mumbikaijonathanben
# !git pull origin main

# !python -m Playground_Mumbi.train_recons \
    --from-hyperparams Playground_Mumbi/checkpoints/best_hyperparams_cnn_lstm.yaml \
    --epochs 150 \
    --batch-size 32 \
    --num-workers 2 \

from google.colab import files
files.download("Playground_Mumbi/checkpoints/best_cnnlstm_recons_v3.pt")
files.download('results/results_summary_CNN_LSTM.csv')
files.download('results/results_curves_CNN_LSTM.csv')
# Out:
# /content/C247_mumbikaijonathanben
# From https://github.com/he-is-kai/C247_mumbikaijonathanben
#  * branch            main       -> FETCH_HEAD
# Already up to date.
# Loaded hyperparameters from Playground_Mumbi/checkpoints/best_hyperparams_cnn_lstm.yaml
#   lr=0.0016150314867822216, weight_decay=4.471967886953457e-05, cnn_channels=384, cnn_kernel=3, cnn_layers=3, lstm_hidden=512, lstm_layers=1, dropout=0.17743104178493208
# Device      : cuda
# Pipeline    : recons_v3 (32-dim @ 62.5 Hz)
# Building data loaders …
# Preloading reconstructed EMG into RAM...
# Done.
#   train_fraction=1.00: using all 3835 training windows
# Recons split — train sessions: 16 | val sessions: 1 | test sessions: 1
#   train batches : 120 | val batches : 7 | test batches : 281
# Model       : CNN+LSTM (recons_v3)
# Parameters  : 5,123,683
# Run ID      : CNN_LSTM_32ch_62.5hz_89pct_20260312_192726
#
# Training for 150 epochs …
# Tip: press Ctrl+C at any time to stop early.
#
# ...
